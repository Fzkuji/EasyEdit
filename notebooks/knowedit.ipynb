# %%
# load dataset from huggingface
from datasets import load_dataset
dataset = load_dataset('zjunlp/KnowEdit')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 # load dataset from huggingface
#       2 from datasets import load_dataset
# ----> 3 dataset = load_dataset('zjunlp/KnowEdit')
#
# File /opt/miniconda3/envs/EasyEdit/lib/python3.9/site-packages/datasets/load.py:1675, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, script_version, **config_kwargs)
#    1672 ignore_verifications = ignore_verifications or save_infos
#    1674 # Create a dataset builder
# -> 1675 builder_instance = load_dataset_builder(
#    1676     path=path,
#    1677     name=name,
#    1678     data_dir=data_dir,
#    1679     data_files=data_files,
#    1680     cache_dir=cache_dir,
#    1681     features=features,
# ...

# %%
# print dataset
print(dataset)
